# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 589

# %%
city_ids = []
Cities = []
country = []
dates = []
clouds = []
humids = []
lats =[]
lngs = []
max_temps =[]
winds = []


cnt = 0
print("  Starting API Test Calls")
print("---------------------------")

for city in cities:
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&units=imperial&APPID={api_key}"
    url = requests.get(url).json()   
    cnt +=1
    print(f"Process #{cnt} for {city}.")
    try:   
        city_id = url["id"]
        city_ids.append(city_id)
        Cities.append(city.title())
        clouds.append(url["clouds"]["all"])
        country.append(url["sys"]["country"])
        date = int(url["dt"])
        date = datetime.utcfromtimestamp(date).strftime('%Y-%m-%d')
        dates.append(date)
        humids.append(url["main"]["humidity"])
        lats.append(url["coord"]["lat"])
        lngs.append(url["coord"]["lon"])
        max_temps.append(url["main"]["temp_max"])
        winds.append(url["wind"]["speed"])  
        print(f"Found: {city} with city id: {city_id}")
    except KeyError:
        print(f"{city} Not Found")
        pass
   
    
print("--------------")
print("  ALL DONE")
# Out:
#   Starting API Test Calls
# ---------------------------
# Process #1 for maceio.
# Found: maceio with city id: 3395981
# Process #2 for cabo san lucas.
# Found: cabo san lucas with city id: 3985710
# Process #3 for adelaide.
# Found: adelaide with city id: 2078025
# Process #4 for nabire.
# Found: nabire with city id: 1634614
# Process #5 for cape town.
# Found: cape town with city id: 3369157
# Process #6 for hermanus.
# Found: hermanus with city id: 3366880
# Process #7 for atuona.
# Found: atuona with city id: 4020109
# Process #8 for bethel.
# Found: bethel with city id: 5880568
# Process #9 for samusu.
# samusu Not Found
# Process #10 for qasigiannguit.
# Found: qasigiannguit with city id: 3420768
# Process #11 for busselton.
# Found: busselton with city id: 2075265
# Process #12 for mataura.
# Found: mataura with city id: 6201424
# Process #13 for kodiak.
# Found: kodiak with city id: 4407665
# Process #14 for parkes.
# Found: parkes with city id: 2153778
# Process #15 for rodna.
# Found: rodna with city id: 668772
# Process #16 for upernavik.
# Found: upernavik with city id: 3418910
# Process #17 for kapaa.
# Found: kapaa with city id: 5848280
# Process #18 for vieksniai.
# Found: vieksniai with city id: 593218
# Process #19 for taolanaro.
# taolanaro Not Found
# Process #20 for rikitea.
# Found: rikitea with city id: 4030556
# Process #21 for chicama.
# Found: chicama with city id: 3698359
# Process #22 for vostok.
# Found: vostok with city id: 2013279
# Process #23 for ushuaia.
# Found: ushuaia with city id: 3833367
# Process #24 for aconibe.
# Found: aconibe with city id: 2310547
# Process #25 for dunedin.
# Found: dunedin with city id: 2191562
# Process #26 for punta arenas.
# Found: punta arenas with city id: 3874787
# Process #27 for opuwo.
# Found: opuwo with city id: 3354077
# Process #28 for korla.
# korla Not Found
# Process #29 for san sebastian el grande.
# Found: san sebastian el grande with city id: 3984791
# Process #30 for touros.
# Found: touros with city id: 3386213
# Process #31 for inhambane.
# Found: inhambane with city id: 1045114
# Process #32 for raudeberg.
# Found: raudeberg with city id: 3146487
# Process #33 for souillac.
# Found: souillac with city id: 3026644
# Process #34 for moroleon.
# Found: moroleon with city id: 3995343
# Process #35 for poya.
# Found: poya with city id: 2138522
# Process #36 for saint-philippe.
# Found: saint-philippe with city id: 6138908
# Process #37 for tuktoyaktuk.
# Found: tuktoyaktuk with city id: 6170031
# Process #38 for chuy.
# Found: chuy with city id: 3443061
# Process #39 for vredendal.
# Found: vredendal with city id: 3359736
# Process #40 for pangnirtung.
# Found: pangnirtung with city id: 6096551
# Process #41 for nikolskoye.
# Found: nikolskoye with city id: 546105
# Process #42 for airai.
# Found: airai with city id: 1651810
# Process #43 for grand river south east.
# grand river south east Not Found
# Process #44 for bluff.
# Found: bluff with city id: 2175403
# Process #45 for lebu.
# Found: lebu with city id: 344979
# Process #46 for mahebourg.
# Found: mahebourg with city id: 934322
# Process #47 for bairiki.
# bairiki Not Found
# Process #48 for albany.
# Found: albany with city id: 5106834
# Process #49 for baghdad.
# Found: baghdad with city id: 98182
# Process #50 for tsihombe.
# tsihombe Not Found
# Process #51 for clyde river.
# Found: clyde river with city id: 5924351
# Process #52 for morehead.
# Found: morehead with city id: 4301307
# Process #53 for babanka.
# Found: babanka with city id: 713055
# Process #54 for port alfred.
# Found: port alfred with city id: 964432
# Process #55 for bredasdorp.
# Found: bredasdorp with city id: 1015776
# Process #56 for vuktyl.
# Found: vuktyl with city id: 470905
# Process #57 for port-gentil.
# Found: port-gentil with city id: 2396518
# Process #58 for lobito.
# Found: lobito with city id: 3347939
# Process #59 for puerto ayora.
# Found: puerto ayora with city id: 3652764
# Process #60 for ribeira grande.
# Found: ribeira grande with city id: 3372707
# Process #61 for griffith.
# Found: griffith with city id: 2164422
# Process #62 for bambous virieux.
# Found: bambous virieux with city id: 1106677
# Process #63 for brae.
# Found: brae with city id: 2654970
# Process #64 for barrow.
# Found: barrow with city id: 3833859
# Process #65 for tromso.
# Found: tromso with city id: 3133895
# Process #66 for porto torres.
# Found: porto torres with city id: 3170069
# Process #67 for butaritari.
# Found: butaritari with city id: 2110227
# Process #68 for worthington.
# Found: worthington with city id: 5053460
# Process #69 for arraial do cabo.
# Found: arraial do cabo with city id: 3471451
# Process #70 for saldanha.
# Found: saldanha with city id: 2737599
# Process #71 for barentsburg.
# barentsburg Not Found
# Process #72 for saleaula.
# saleaula Not Found
# Process #73 for cidreira.
# Found: cidreira with city id: 3466165
# Process #74 for margate.
# Found: margate with city id: 2158744
# Process #75 for baft.
# Found: baft with city id: 390054
# Process #76 for khatanga.
# Found: khatanga with city id: 2022572
# Process #77 for alugan.
# Found: alugan with city id: 1731248
# Process #78 for na wa.
# Found: na wa with city id: 1608399
# Process #79 for thinadhoo.
# Found: thinadhoo with city id: 1337610
# Process #80 for mezhdurechensk.
# Found: mezhdurechensk with city id: 1498920
# Process #81 for salta.
# Found: salta with city id: 3838233
# Process #82 for vao.
# Found: vao with city id: 588365
# Process #83 for luderitz.
# Found: luderitz with city id: 3355672
# Process #84 for thompson.
# Found: thompson with city id: 6165406
# Process #85 for banda aceh.
# Found: banda aceh with city id: 1215502
# Process #86 for riyadh.
# Found: riyadh with city id: 108410
# Process #87 for tiksi.
# Found: tiksi with city id: 2015306
# Process #88 for bathsheba.
# Found: bathsheba with city id: 3374083
# Process #89 for mount isa.
# Found: mount isa with city id: 2065594
# Process #90 for namibe.
# Found: namibe with city id: 3347019
# Process #91 for new norfolk.
# Found: new norfolk with city id: 2155415
# Process #92 for narsaq.
# Found: narsaq with city id: 3421719
# Process #93 for port elizabeth.
# Found: port elizabeth with city id: 4501427
# Process #94 for dikson.
# Found: dikson with city id: 1507390
# Process #95 for fritzlar.
# Found: fritzlar with city id: 2924326
# Process #96 for rapid valley.
# Found: rapid valley with city id: 5768244
# Process #97 for nizwa.
# Found: nizwa with city id: 286987
# Process #98 for rio gallegos.
# Found: rio gallegos with city id: 3838859
# Process #99 for kuche.
# kuche Not Found
# Process #100 for acapulco.
# Found: acapulco with city id: 3533462
# Process #101 for jamestown.
# Found: jamestown with city id: 2069194
# Process #102 for the valley.
# Found: the valley with city id: 3573374
# Process #103 for ahipara.
# Found: ahipara with city id: 2194098
# Process #104 for gairatganj.
# Found: gairatganj with city id: 1255895
# Process #105 for chokurdakh.
# Found: chokurdakh with city id: 2126123
# Process #106 for east london.
# Found: east london with city id: 1006984
# Process #107 for qaanaaq.
# Found: qaanaaq with city id: 3831208
# Process #108 for peddapuram.
# Found: peddapuram with city id: 1259954
# Process #109 for monkey bay.
# Found: monkey bay with city id: 926308
# Process #110 for mavrovi anovi.
# Found: mavrovi anovi with city id: 790295
# Process #111 for piuma.
# Found: piuma with city id: 3453435
# Process #112 for ozinki.
# Found: ozinki with city id: 513328
# Process #113 for nishihara.
# Found: nishihara with city id: 1850144
# Process #114 for yulara.
# Found: yulara with city id: 6355222
# Process #115 for atar.
# Found: atar with city id: 2381334
# Process #116 for hilo.
# Found: hilo with city id: 5855927
# Process #117 for eureka.
# Found: eureka with city id: 5563397
# Process #118 for necochea.
# Found: necochea with city id: 3430443
# Process #119 for ardmore.
# Found: ardmore with city id: 4602982
# Process #120 for mackay.
# Found: mackay with city id: 5921525
# Process #121 for guerrero negro.
# Found: guerrero negro with city id: 4021858
# Process #122 for victoria.
# Found: victoria with city id: 1733782
# Process #123 for koslan.
# Found: koslan with city id: 544084
# Process #124 for sioux lookout.
# Found: sioux lookout with city id: 6148373
# Process #125 for los llanos de aridane.
# Found: los llanos de aridane with city id: 2514651
# Process #126 for vila.
# Found: vila with city id: 3164565
# Process #127 for kaitangata.
# Found: kaitangata with city id: 2208248
# Process #128 for yar-sale.
# Found: yar-sale with city id: 1486321
# Process #129 for tambun.
# Found: tambun with city id: 1649378
# Process #130 for zhigansk.
# Found: zhigansk with city id: 2012530
# Process #131 for illoqqortoormiut.
# illoqqortoormiut Not Found
# Process #132 for dakoro.
# Found: dakoro with city id: 2446267
# Process #133 for luanda.
# Found: luanda with city id: 2240449
# Process #134 for saskylakh.
# Found: saskylakh with city id: 2017155
# Process #135 for grand forks.
# Found: grand forks with city id: 5059429
# Process #136 for svetlogorsk.
# Found: svetlogorsk with city id: 584051
# Process #137 for shimoda.
# Found: shimoda with city id: 1852357
# Process #138 for imeni poliny osipenko.
# Found: imeni poliny osipenko with city id: 2023584
# Process #139 for culfa.
# Found: culfa with city id: 148251
# Process #140 for stromness.
# Found: stromness with city id: 5914857
# Process #141 for nizhneyansk.
# nizhneyansk Not Found
# Process #142 for cardston.
# Found: cardston with city id: 5916821
# Process #143 for bandar penggaram.
# bandar penggaram Not Found
# Process #144 for camocim.
# Found: camocim with city id: 3403687
# Process #145 for lagoa.
# Found: lagoa with city id: 2267254
# Process #146 for vaitupu.
# vaitupu Not Found
# Process #147 for longkou.
# Found: longkou with city id: 1802550
# Process #148 for hithadhoo.
# Found: hithadhoo with city id: 1282256
# Process #149 for georgetown.
# Found: georgetown with city id: 3378644
# Process #150 for provideniya.
# Found: provideniya with city id: 4031574
# Process #151 for amderma.
# amderma Not Found
# Process #152 for tadine.
# Found: tadine with city id: 2138285
# Process #153 for buraydah.
# Found: buraydah with city id: 107304
# Process #154 for saint anthony.
# Found: saint anthony with city id: 5606187
# Process #155 for sitka.
# Found: sitka with city id: 4267710
# Process #156 for ucluelet.
# Found: ucluelet with city id: 6171633
# Process #157 for jinchengjiang.
# jinchengjiang Not Found
# Process #158 for komsomolskiy.
# Found: komsomolskiy with city id: 1486910
# Process #159 for kathu.
# Found: kathu with city id: 991664
# Process #160 for isangel.
# Found: isangel with city id: 2136825
# Process #161 for florianopolis.
# Found: florianopolis with city id: 3463237
# Process #162 for kamenskoye.
# kamenskoye Not Found
# Process #163 for ballina.
# Found: ballina with city id: 2966778
# Process #164 for aktau.
# Found: aktau with city id: 610612
# Process #165 for kruisfontein.
# Found: kruisfontein with city id: 986717
# Process #166 for gort.
# Found: gort with city id: 2963958
# Process #167 for seoul.
# Found: seoul with city id: 1835848
# Process #168 for omboue.
# Found: omboue with city id: 2396853
# Process #169 for nanortalik.
# Found: nanortalik with city id: 3421765
# Process #170 for castro.
# Found: castro with city id: 3896218
# Process #171 for hobart.
# Found: hobart with city id: 2163355
# Process #172 for mar del plata.
# Found: mar del plata with city id: 3863379
# Process #173 for pevek.
# Found: pevek with city id: 2122090
# Process #174 for turukhansk.
# Found: turukhansk with city id: 1488903
# Process #175 for yerbogachen.
# Found: yerbogachen with city id: 2012956
# Process #176 for el colomo.
# Found: el colomo with city id: 4004293
# Process #177 for dalbandin.
# Found: dalbandin with city id: 1180729
# Process #178 for warqla.
# warqla Not Found
# Process #179 for bilibino.
# Found: bilibino with city id: 2126682
# Process #180 for porto novo.
# Found: porto novo with city id: 6322184
# Process #181 for puerto leguizamo.
# Found: puerto leguizamo with city id: 3671437
# Process #182 for tasiilaq.
# Found: tasiilaq with city id: 3424607
# Process #183 for ostrovnoy.
# Found: ostrovnoy with city id: 556268
# Process #184 for faanui.
# Found: faanui with city id: 4034551
# Process #185 for galiwinku.
# galiwinku Not Found
# Process #186 for attawapiskat.
# attawapiskat Not Found
# Process #187 for haines junction.
# Found: haines junction with city id: 5969025
# Process #188 for vaini.
# Found: vaini with city id: 1273574
# Process #189 for visby.
# Found: visby with city id: 2662689
# Process #190 for santa vitoria do palmar.
# Found: santa vitoria do palmar with city id: 3449747
# Process #191 for belushya guba.
# belushya guba Not Found
# Process #192 for fare.
# Found: fare with city id: 4034496
# Process #193 for zdunska wola.
# Found: zdunska wola with city id: 3080414
# Process #194 for sao jose da coroa grande.
# Found: sao jose da coroa grande with city id: 3388456
# Process #195 for leningradskiy.
# Found: leningradskiy with city id: 2123814
# Process #196 for rio grande.
# Found: rio grande with city id: 3451138
# Process #197 for tumannyy.
# tumannyy Not Found
# Process #198 for constitucion.
# Found: constitucion with city id: 4011743
# Process #199 for san felipe.
# Found: san felipe with city id: 3872255
# Process #200 for awjilah.
# Found: awjilah with city id: 88533
# Process #201 for lushoto.
# Found: lushoto with city id: 155569
# Process #202 for toliary.
# toliary Not Found
# Process #203 for louisbourg.
# louisbourg Not Found
# Process #204 for mangrol.
# Found: mangrol with city id: 1263751
# Process #205 for morondava.
# Found: morondava with city id: 1058381
# Process #206 for sao geraldo do araguaia.
# Found: sao geraldo do araguaia with city id: 3388760
# Process #207 for barawe.
# barawe Not Found
# Process #208 for moorhead.
# Found: moorhead with city id: 5038108
# Process #209 for avarua.
# Found: avarua with city id: 4035715
# Process #210 for karratha.
# Found: karratha with city id: 6620339
# Process #211 for mnogovershinnyy.
# Found: mnogovershinnyy with city id: 2019935
# Process #212 for maniitsoq.
# Found: maniitsoq with city id: 3421982
# Process #213 for tuatapere.
# Found: tuatapere with city id: 2180815
# Process #214 for santa luzia.
# Found: santa luzia with city id: 3450144
# Process #215 for san martin.
# Found: san martin with city id: 4005143
# Process #216 for hojai.
# Found: hojai with city id: 1269993
# Process #217 for aswan.
# Found: aswan with city id: 359792
# Process #218 for longyearbyen.
# Found: longyearbyen with city id: 2729907
# Process #219 for kindu.
# Found: kindu with city id: 212902
# Process #220 for jiddah.
# jiddah Not Found
# Process #221 for lompoc.
# Found: lompoc with city id: 5367788
# Process #222 for ankara.
# Found: ankara with city id: 323786
# Process #223 for lorengau.
# Found: lorengau with city id: 2092164
# Process #224 for vestmanna.
# Found: vestmanna with city id: 2610343
# Process #225 for poronaysk.
# Found: poronaysk with city id: 2121909
# Process #226 for poyarkovo.
# Found: poyarkovo with city id: 2017705
# Process #227 for caravelas.
# Found: caravelas with city id: 3466980
# Process #228 for el tigre.
# Found: el tigre with city id: 3641351
# Process #229 for suarez.
# Found: suarez with city id: 3667772
# Process #230 for carutapera.
# Found: carutapera with city id: 3402648
# Process #231 for san patricio.
# Found: san patricio with city id: 3437029
# Process #232 for havre-saint-pierre.
# Found: havre-saint-pierre with city id: 5972291
# Process #233 for hastings.
# Found: hastings with city id: 2190224
# Process #234 for marcona.
# marcona Not Found
# Process #235 for aklavik.
# Found: aklavik with city id: 5882953
# Process #236 for klaksvik.
# Found: klaksvik with city id: 2618795
# Process #237 for sakaiminato.
# Found: sakaiminato with city id: 1853174
# Process #238 for hervey bay.
# Found: hervey bay with city id: 2146219
# Process #239 for fomboni.
# Found: fomboni with city id: 921889
# Process #240 for novobirilyussy.
# Found: novobirilyussy with city id: 1508260
# Process #241 for honningsvag.
# Found: honningsvag with city id: 779554
# Process #242 for sentyabrskiy.
# sentyabrskiy Not Found
# Process #243 for goderich.
# Found: goderich with city id: 5962442
# Process #244 for mys shmidta.
# mys shmidta Not Found
# Process #245 for harper.
# Found: harper with city id: 4696310
# Process #246 for hami.
# Found: hami with city id: 1529484
# Process #247 for fortuna.
# Found: fortuna with city id: 5563839
# Process #248 for juneau.
# Found: juneau with city id: 5554072
# Process #249 for hudson bay.
# Found: hudson bay with city id: 5978133
# Process #250 for bani walid.
# Found: bani walid with city id: 2218840
# Process #251 for mamontovo.
# Found: mamontovo with city id: 1499428
# Process #252 for gat.
# Found: gat with city id: 2249901
# Process #253 for sibolga.
# Found: sibolga with city id: 1213855
# Process #254 for abha.
# Found: abha with city id: 110690
# Process #255 for esperance.
# Found: esperance with city id: 2071860
# Process #256 for vila franca do campo.
# Found: vila franca do campo with city id: 3372472
# Process #257 for bima.
# Found: bima with city id: 1648759
# Process #258 for kerouane.
# Found: kerouane with city id: 2417886
# Process #259 for daguit.
# Found: daguit with city id: 1716213
# Process #260 for chernyshevskiy.
# Found: chernyshevskiy with city id: 2025456
# Process #261 for moron.
# Found: moron with city id: 3720455
# Process #262 for zhongshu.
# Found: zhongshu with city id: 1784310
# Process #263 for rorvik.
# Found: rorvik with city id: 3141310
# Process #264 for geraldton.
# Found: geraldton with city id: 5960603
# Process #265 for matara.
# Found: matara with city id: 425378
# Process #266 for ipixuna.
# Found: ipixuna with city id: 3408424
# Process #267 for eyl.
# Found: eyl with city id: 60019
# Process #268 for kavaratti.
# Found: kavaratti with city id: 1267390
# Process #269 for qaqortoq.
# Found: qaqortoq with city id: 3420846
# Process #270 for lawrenceburg.
# Found: lawrenceburg with city id: 4635849
# Process #271 for kon tum.
# Found: kon tum with city id: 1578500
# Process #272 for ksenyevka.
# ksenyevka Not Found
# Process #273 for tukums.
# Found: tukums with city id: 454768
# Process #274 for fianga.
# fianga Not Found
# Process #275 for longlac.
# longlac Not Found
# Process #276 for kununurra.
# Found: kununurra with city id: 2068110
# Process #277 for sawakin.
# Found: sawakin with city id: 367544
# Process #278 for santa isabel do rio negro.
# Found: santa isabel do rio negro with city id: 3662489
# Process #279 for sao joao da barra.
# Found: sao joao da barra with city id: 3448903
# Process #280 for corinto.
# Found: corinto with city id: 3685871
# Process #281 for norman wells.
# Found: norman wells with city id: 6089245
# Process #282 for bardiyah.
# bardiyah Not Found
# Process #283 for hoi an.
# Found: hoi an with city id: 1580541
# Process #284 for astoria.
# Found: astoria with city id: 5711847
# Process #285 for shache.
# Found: shache with city id: 1280037
# Process #286 for hamilton.
# Found: hamilton with city id: 5969785
# Process #287 for katsuura.
# Found: katsuura with city id: 1865309
# Process #288 for pontal do parana.
# Found: pontal do parana with city id: 3478424
# Process #289 for santa marta.
# Found: santa marta with city id: 3668605
# Process #290 for fort nelson.
# Found: fort nelson with city id: 5955902
# Process #291 for obihiro.
# Found: obihiro with city id: 2128815
# Process #292 for hannut.
# Found: hannut with city id: 2796583
# Process #293 for saint-augustin.
# Found: saint-augustin with city id: 6138501
# Process #294 for xiaoweizhai.
# Found: xiaoweizhai with city id: 1789945
# Process #295 for ayan.
# Found: ayan with city id: 117656
# Process #296 for viesca.
# Found: viesca with city id: 3980230
# Process #297 for broome.
# Found: broome with city id: 2656067
# Process #298 for halalo.
# halalo Not Found
# Process #299 for manavalakurichi.
# Found: manavalakurichi with city id: 1263942
# Process #300 for ilulissat.
# Found: ilulissat with city id: 3423146
# Process #301 for nome.
# Found: nome with city id: 4732862
# Process #302 for hasaki.
# Found: hasaki with city id: 2112802
# Process #303 for guangyuan.
# Found: guangyuan with city id: 1806466
# Process #304 for talnakh.
# Found: talnakh with city id: 1490256
# Process #305 for maltahohe.
# Found: maltahohe with city id: 3355624
# Process #306 for yellowknife.
# Found: yellowknife with city id: 6185377
# Process #307 for gornyy.
# Found: gornyy with city id: 559731
# Process #308 for salalah.
# Found: salalah with city id: 286621
# Process #309 for jaciara.
# Found: jaciara with city id: 3460355
# Process #310 for beipiao.
# Found: beipiao with city id: 2038342
# Process #311 for tuytepa.
# Found: tuytepa with city id: 1512524
# Process #312 for puyang.
# Found: puyang with city id: 1798422
# Process #313 for ravar.
# Found: ravar with city id: 118704
# Process #314 for teahupoo.
# Found: teahupoo with city id: 4033543
# Process #315 for kundiawa.
# Found: kundiawa with city id: 2093059
# Process #316 for kavieng.
# Found: kavieng with city id: 2094342
# Process #317 for ekhabi.
# Found: ekhabi with city id: 2122614
# Process #318 for ponta do sol.
# Found: ponta do sol with city id: 3453439
# Process #319 for sabha.
# Found: sabha with city id: 2212775
# Process #320 for codrington.
# Found: codrington with city id: 2160063
# Process #321 for takoradi.
# Found: takoradi with city id: 2294915
# Process #322 for puerto ayacucho.
# Found: puerto ayacucho with city id: 3629710
# Process #323 for praia.
# Found: praia with city id: 3460954
# Process #324 for grand gaube.
# Found: grand gaube with city id: 934479
# Process #325 for horta.
# Found: horta with city id: 3459342
# Process #326 for barbar.
# barbar Not Found
# Process #327 for siirt.
# Found: siirt with city id: 300822
# Process #328 for knysna.
# Found: knysna with city id: 988698
# Process #329 for vangaindrano.
# Found: vangaindrano with city id: 1054329
# Process #330 for rio verde de mato grosso.
# Found: rio verde de mato grosso with city id: 3451051
# Process #331 for carnarvon.
# Found: carnarvon with city id: 1014034
# Process #332 for naftah.
# naftah Not Found
# Process #333 for donskoye.
# Found: donskoye with city id: 565289
# Process #334 for palabuhanratu.
# palabuhanratu Not Found
# Process #335 for grand-lahou.
# Found: grand-lahou with city id: 2288105
# Process #336 for san cristobal.
# Found: san cristobal with city id: 3609418
# Process #337 for mukhen.
# Found: mukhen with city id: 2019718
# Process #338 for zolotinka.
# zolotinka Not Found
# Process #339 for minsk.
# Found: minsk with city id: 625144
# Process #340 for asau.
# asau Not Found
# Process #341 for coihaique.
# Found: coihaique with city id: 3894426
# Process #342 for ntchisi.
# Found: ntchisi with city id: 927384
# Process #343 for chulman.
# Found: chulman with city id: 2025261
# Process #344 for kalianget.
# Found: kalianget with city id: 1621395
# Process #345 for lagunas.
# Found: lagunas with city id: 3695844
# Process #346 for te anau.
# Found: te anau with city id: 2181625
# Process #347 for pavda.
# pavda Not Found
# Process #348 for greece.
# Found: greece with city id: 5119251
# Process #349 for santa rita.
# Found: santa rita with city id: 3389321
# Process #350 for barcelos.
# Found: barcelos with city id: 3665098
# Process #351 for sataua.
# sataua Not Found
# Process #352 for ondorhaan.
# ondorhaan Not Found
# Process #353 for sokoto.
# Found: sokoto with city id: 2322911
# Process #354 for teya.
# Found: teya with city id: 3526662
# Process #355 for tomatlan.
# Found: tomatlan with city id: 3981391
# Process #356 for mergui.
# mergui Not Found
# Process #357 for coquimbo.
# Found: coquimbo with city id: 3893629
# Process #358 for balikpapan.
# Found: balikpapan with city id: 1650527
# Process #359 for woodward.
# Found: woodward with city id: 4556050
# Process #360 for nybro.
# Found: nybro with city id: 2687902
# Process #361 for quatre cocos.
# Found: quatre cocos with city id: 1106643
# Process #362 for tarauaca.
# Found: tarauaca with city id: 3661980
# Process #363 for chamonix-mont-blanc.
# Found: chamonix-mont-blanc with city id: 3027301
# Process #364 for salcininkai.
# Found: salcininkai with city id: 595016
# Process #365 for lasa.
# Found: lasa with city id: 146639
# Process #366 for port lincoln.
# Found: port lincoln with city id: 2063036
# Process #367 for aykhal.
# Found: aykhal with city id: 2027296
# Process #368 for honiara.
# Found: honiara with city id: 2108502
# Process #369 for poum.
# Found: poum with city id: 787487
# Process #370 for torbay.
# Found: torbay with city id: 6167817
# Process #371 for caraquet.
# Found: caraquet with city id: 6942803
# Process #372 for saeby.
# Found: saeby with city id: 2614172
# Process #373 for bloemfontein.
# Found: bloemfontein with city id: 1018725
# Process #374 for millinocket.
# Found: millinocket with city id: 4972220
# Process #375 for bargal.
# bargal Not Found
# Process #376 for de land.
# Found: de land with city id: 4902567
# Process #377 for gawler.
# Found: gawler with city id: 2071059
# Process #378 for kahului.
# Found: kahului with city id: 5847411
# Process #379 for posse.
# Found: posse with city id: 3452599
# Process #380 for altay.
# Found: altay with city id: 1529651
# Process #381 for husavik.
# Found: husavik with city id: 5961417
# Process #382 for great yarmouth.
# Found: great yarmouth with city id: 2647984
# Process #383 for marienburg.
# Found: marienburg with city id: 2803461
# Process #384 for yagodnoye.
# Found: yagodnoye with city id: 2119626
# Process #385 for hays.
# Found: hays with city id: 4272782
# Process #386 for belaya gora.
# Found: belaya gora with city id: 2126785
# Process #387 for safford.
# Found: safford with city id: 5312476
# Process #388 for kazalinsk.
# kazalinsk Not Found
# Process #389 for pemangkat.
# pemangkat Not Found
# Process #390 for kingston upon hull.
# kingston upon hull Not Found
# Process #391 for yuryevets.
# Found: yuryevets with city id: 466258
# Process #392 for oriximina.
# Found: oriximina with city id: 3393471
# Process #393 for walvis bay.
# Found: walvis bay with city id: 3359638
# Process #394 for ancud.
# Found: ancud with city id: 3899695
# Process #395 for fiche.
# Found: fiche with city id: 337771
# Process #396 for meulaboh.
# Found: meulaboh with city id: 1214488
# Process #397 for cherskiy.
# Found: cherskiy with city id: 2126199
# Process #398 for makakilo city.
# Found: makakilo city with city id: 5850554
# Process #399 for bandarbeyla.
# Found: bandarbeyla with city id: 64814
# Process #400 for comodoro rivadavia.
# Found: comodoro rivadavia with city id: 3860443
# Process #401 for faya.
# Found: faya with city id: 110690
# Process #402 for amapa.
# Found: amapa with city id: 3603330
# Process #403 for acara.
# acara Not Found
# Process #404 for vanavara.
# Found: vanavara with city id: 2013727
# Process #405 for mahon.
# Found: mahon with city id: 2965139
# Process #406 for casablanca.
# Found: casablanca with city id: 2553604
# Process #407 for artigas.
# Found: artigas with city id: 3443758
# Process #408 for beloha.
# Found: beloha with city id: 1067565
# Process #409 for agua verde.
# Found: agua verde with city id: 4019219
# Process #410 for yialos.
# yialos Not Found
# Process #411 for itarema.
# Found: itarema with city id: 3393692
# Process #412 for forbes.
# Found: forbes with city id: 2166368
# Process #413 for slave lake.
# Found: slave lake with city id: 6149374
# Process #414 for vershino-darasunskiy.
# Found: vershino-darasunskiy with city id: 2013442
# Process #415 for kuryk.
# Found: kuryk with city id: 609919
# Process #416 for beringovskiy.
# Found: beringovskiy with city id: 2126710
# Process #417 for palmer.
# Found: palmer with city id: 2067070
# Process #418 for mumbwa.
# Found: mumbwa with city id: 904422
# Process #419 for dwarka.
# Found: dwarka with city id: 1273294
# Process #420 for daru.
# Found: daru with city id: 2098329
# Process #421 for kushima.
# Found: kushima with city id: 1895695
# Process #422 for saint-joseph.
# Found: saint-joseph with city id: 3037456
# Process #423 for solhan.
# Found: solhan with city id: 300377
# Process #424 for olinda.
# Found: olinda with city id: 2154386
# Process #425 for palana.
# Found: palana with city id: 2122262
# Process #426 for okhotsk.
# Found: okhotsk with city id: 2122605
# Process #427 for adrar.
# Found: adrar with city id: 2508813
# Process #428 for saint george.
# Found: saint george with city id: 262462
# Process #429 for marawi.
# Found: marawi with city id: 1701054
# Process #430 for biak.
# Found: biak with city id: 1637001
# Process #431 for hobyo.
# Found: hobyo with city id: 57000
# Process #432 for antri.
# antri Not Found
# Process #433 for whyalla.
# Found: whyalla with city id: 2058430
# Process #434 for bonthe.
# Found: bonthe with city id: 2409914
# Process #435 for venafro.
# Found: venafro with city id: 3164621
# Process #436 for sao filipe.
# Found: sao filipe with city id: 3374210
# Process #437 for bereda.
# Found: bereda with city id: 3105522
# Process #438 for hamada.
# Found: hamada with city id: 1863310
# Process #439 for banjar.
# Found: banjar with city id: 1650233
# Process #440 for yuzhno-kurilsk.
# Found: yuzhno-kurilsk with city id: 2119447
# Process #441 for kloulklubed.
# Found: kloulklubed with city id: 7671223
# Process #442 for la ronge.
# Found: la ronge with city id: 6050066
# Process #443 for seydi.
# Found: seydi with city id: 2448024
# Process #444 for ambanja.
# Found: ambanja with city id: 1083724
# Process #445 for ilo.
# Found: ilo with city id: 3938415
# Process #446 for hovd.
# Found: hovd with city id: 7626384
# Process #447 for san francisco.
# Found: san francisco with city id: 3669881
# Process #448 for south bend.
# Found: south bend with city id: 4926563
# Process #449 for kaeo.
# Found: kaeo with city id: 2189343
# Process #450 for tunduru.
# tunduru Not Found
# Process #451 for tabiauea.
# tabiauea Not Found
# Process #452 for yumen.
# Found: yumen with city id: 1528998
# Process #453 for severo-kurilsk.
# Found: severo-kurilsk with city id: 2121385
# Process #454 for marzuq.
# Found: marzuq with city id: 72181
# Process #455 for sur.
# Found: sur with city id: 286245
# Process #456 for adre.
# Found: adre with city id: 245669
# Process #457 for boke.
# Found: boke with city id: 2422924
# Process #458 for kerema.
# Found: kerema with city id: 2094144
# Process #459 for dali.
# Found: dali with city id: 1814092
# Process #460 for xique-xique.
# Found: xique-xique with city id: 3444823
# Process #461 for nguiu.
# nguiu Not Found
# Process #462 for russell.
# Found: russell with city id: 4278471
# Process #463 for dillon.
# Found: dillon with city id: 5648657
# Process #464 for maldonado.
# Found: maldonado with city id: 3441894
# Process #465 for santa ana.
# Found: santa ana with city id: 3984717
# Process #466 for eatonton.
# Found: eatonton with city id: 4192800
# Process #467 for port hardy.
# Found: port hardy with city id: 6111862
# Process #468 for paita.
# Found: paita with city id: 3694112
# Process #469 for cuiluan.
# Found: cuiluan with city id: 2033413
# Process #470 for chulym.
# Found: chulym with city id: 1507679
# Process #471 for ust-tsilma.
# Found: ust-tsilma with city id: 477940
# Process #472 for california city.
# Found: california city with city id: 5332748
# Process #473 for las varas.
# Found: las varas with city id: 3999162
# Process #474 for baker city.
# Found: baker city with city id: 5712169
# Process #475 for sungairaya.
# Found: sungairaya with city id: 1625908
# Process #476 for cabedelo.
# Found: cabedelo with city id: 3404558
# Process #477 for zhigalovo.
# Found: zhigalovo with city id: 2012532
# Process #478 for trairi.
# Found: trairi with city id: 3386177
# Process #479 for cascais.
# Found: cascais with city id: 2269594
# Process #480 for kulachi.
# Found: kulachi with city id: 1172779
# Process #481 for marau.
# Found: marau with city id: 3457817
# Process #482 for anar darreh.
# anar darreh Not Found
# Process #483 for tymovskoye.
# Found: tymovskoye with city id: 2120334
# Process #484 for lichinga.
# Found: lichinga with city id: 1043893
# Process #485 for port blair.
# Found: port blair with city id: 1259385
# Process #486 for catuday.
# Found: catuday with city id: 1717787
# Process #487 for bombay.
# Found: bombay with city id: 5928065
# Process #488 for solana beach.
# Found: solana beach with city id: 5396974
# Process #489 for jonava.
# Found: jonava with city id: 598818
# Process #490 for haibowan.
# haibowan Not Found
# Process #491 for igarka.
# Found: igarka with city id: 1505991
# Process #492 for nantucket.
# Found: nantucket with city id: 4944903
# Process #493 for lufilufi.
# Found: lufilufi with city id: 4035249
# Process #494 for pandan.
# Found: pandan with city id: 1695555
# Process #495 for sao gabriel da cachoeira.
# Found: sao gabriel da cachoeira with city id: 3662342
# Process #496 for berlevag.
# Found: berlevag with city id: 780687
# Process #497 for cuenca.
# Found: cuenca with city id: 3658666
# Process #498 for kalmunai.
# Found: kalmunai with city id: 1242110
# Process #499 for acajutla.
# Found: acajutla with city id: 3587498
# Process #500 for tottori.
# Found: tottori with city id: 1849892
# Process #501 for kailua.
# Found: kailua with city id: 5847486
# Process #502 for ternovskaya.
# Found: ternovskaya with city id: 483326
# Process #503 for nortelandia.
# Found: nortelandia with city id: 3456248
# Process #504 for akita.
# Found: akita with city id: 2113126
# Process #505 for lima.
# Found: lima with city id: 3936456
# Process #506 for khani.
# Found: khani with city id: 610864
# Process #507 for sergeyevka.
# Found: sergeyevka with city id: 1519385
# Process #508 for calvinia.
# Found: calvinia with city id: 3369174
# Process #509 for malm.
# Found: malm with city id: 3146508
# Process #510 for severnyy.
# severnyy Not Found
# Process #511 for mount gambier.
# Found: mount gambier with city id: 2156643
# Process #512 for laguna.
# Found: laguna with city id: 3581398
# Process #513 for naze.
# Found: naze with city id: 2337542
# Process #514 for eganville.
# Found: eganville with city id: 5947035
# Process #515 for howard springs.
# Found: howard springs with city id: 6301965
# Process #516 for ondangwa.
# Found: ondangwa with city id: 3354247
# Process #517 for trincomalee.
# Found: trincomalee with city id: 1226260
# Process #518 for ambilobe.
# Found: ambilobe with city id: 1082243
# Process #519 for treinta y tres.
# Found: treinta y tres with city id: 3439781
# Process #520 for amuntai.
# Found: amuntai with city id: 1651461
# Process #521 for cap malheureux.
# Found: cap malheureux with city id: 934649
# Process #522 for farafangana.
# Found: farafangana with city id: 1065158
# Process #523 for labuhan.
# Found: labuhan with city id: 1641899
# Process #524 for fairbanks.
# Found: fairbanks with city id: 5861897
# Process #525 for mandi bahauddin.
# Found: mandi bahauddin with city id: 1171123
# Process #526 for port hedland.
# Found: port hedland with city id: 2063042
# Process #527 for fallon.
# Found: fallon with city id: 5681948
# Process #528 for iquitos.
# Found: iquitos with city id: 3696183
# Process #529 for bonavista.
# Found: bonavista with city id: 5905393
# Process #530 for cabcab.
# Found: cabcab with city id: 1721660
# Process #531 for havelock.
# Found: havelock with city id: 4470244
# Process #532 for bubaque.
# Found: bubaque with city id: 2374583
# Process #533 for vestmannaeyjar.
# Found: vestmannaeyjar with city id: 3412093
# Process #534 for sorong.
# Found: sorong with city id: 1626542
# Process #535 for rabo de peixe.
# Found: rabo de peixe with city id: 3372745
# Process #536 for cockburn town.
# Found: cockburn town with city id: 3576994
# Process #537 for tilichiki.
# Found: tilichiki with city id: 2120591
# Process #538 for abnub.
# Found: abnub with city id: 362973
# Process #539 for naftalan.
# Found: naftalan with city id: 585400
# Process #540 for cacahuatepec.
# Found: cacahuatepec with city id: 3531263
# Process #541 for sterling.
# Found: sterling with city id: 4787534
# Process #542 for emerald.
# Found: emerald with city id: 2167426
# Process #543 for portales.
# Found: portales with city id: 5484874
# Process #544 for angoram.
# Found: angoram with city id: 2100765
# Process #545 for san jose de buan.
# Found: san jose de buan with city id: 1689399
# Process #546 for lingao.
# Found: lingao with city id: 1803560
# Process #547 for ankazoabo.
# Found: ankazoabo with city id: 1072879
# Process #548 for lolua.
# lolua Not Found
# Process #549 for toungoo.
# toungoo Not Found
# Process #550 for jaisalmer.
# Found: jaisalmer with city id: 1269507
# Process #551 for qom.
# Found: qom with city id: 119208
# Process #552 for kalaleh.
# Found: kalaleh with city id: 129512
# Process #553 for stephenville crossing.
# Found: stephenville crossing with city id: 6156245
# Process #554 for san juan.
# Found: san juan with city id: 3837213
# Process #555 for yeniseysk.
# Found: yeniseysk with city id: 1485997
# Process #556 for lavrentiya.
# Found: lavrentiya with city id: 4031637
# Process #557 for balkhash.
# Found: balkhash with city id: 1525798
# Process #558 for ronne.
# Found: ronne with city id: 2991703
# Process #559 for coelho neto.
# Found: coelho neto with city id: 3401992
# Process #560 for mendahara.
# mendahara Not Found
# Process #561 for hirara.
# Found: hirara with city id: 1862505
# Process #562 for aitape.
# Found: aitape with city id: 2101169
# Process #563 for albino.
# Found: albino with city id: 6540342
# Process #564 for ulladulla.
# Found: ulladulla with city id: 2145554
# Process #565 for iskateley.
# Found: iskateley with city id: 866062
# Process #566 for chimbote.
# Found: chimbote with city id: 3698304
# Process #567 for tonj.
# tonj Not Found
# Process #568 for wajir.
# Found: wajir with city id: 178443
# Process #569 for arica.
# Found: arica with city id: 3899361
# Process #570 for sri aman.
# Found: sri aman with city id: 1735799
# Process #571 for banjul.
# Found: banjul with city id: 2413876
# Process #572 for jiaocheng.
# Found: jiaocheng with city id: 1806041
# Process #573 for mwingi.
# Found: mwingi with city id: 184921
# Process #574 for guamuchil.
# Found: guamuchil with city id: 4005297
# Process #575 for muli.
# Found: muli with city id: 7304020
# Process #576 for krasnyy chikoy.
# Found: krasnyy chikoy with city id: 2012349
# Process #577 for dingle.
# Found: dingle with city id: 1714733
# Process #578 for kieta.
# Found: kieta with city id: 2094027
# Process #579 for drinovci.
# Found: drinovci with city id: 3190941
# Process #580 for hay river.
# Found: hay river with city id: 5972762
# Process #581 for barranquilla.
# Found: barranquilla with city id: 3689147
# Process #582 for gambela.
# Found: gambela with city id: 337405
# Process #583 for pombas.
# Found: pombas with city id: 3448350
# Process #584 for muncar.
# Found: muncar with city id: 1634718
# Process #585 for sinnamary.
# Found: sinnamary with city id: 3380290
# Process #586 for haysville.
# Found: haysville with city id: 4272788
# Process #587 for udachnyy.
# Found: udachnyy with city id: 2014624
# Process #588 for moerai.
# Found: moerai with city id: 4034188
# Process #589 for quang ngai.
# Found: quang ngai with city id: 1568770
# --------------
#   ALL DONE

# %%
#Making a DataFrame to hold informations pulled from API
weather_df = pd.DataFrame(columns = ["City","Country","Date","Cloudiness","Humidity","Lat","Lng","Max Temp","Wind Speed"])
weather_df["City"] = Cities
weather_df["Country"] = country
weather_df["Date"] = date
weather_df["Cloudiness"] = clouds
weather_df["Humidity"] = humids
weather_df["Lat"] = lats
weather_df["Lng"] = lngs
weather_df["Max Temp"] = max_temps
weather_df["Wind Speed"] = winds
weather_df.head()
# Out:
#              City Country        Date  Cloudiness  Humidity    Lat     Lng  \
# 0          Maceio      BR  2019-06-27          75        69  -9.67  -35.74
# 1  Cabo San Lucas      MX  2019-06-27          40        46  22.89 -109.91
# 2        Adelaide      AU  2019-06-27           0        51 -34.93  138.60
# 3          Nabire      ID  2019-06-27         100        99  -3.36  135.50
# 4       Cape Town      ZA  2019-06-27          75        82 -33.93   18.42
#
#    Max Temp  Wind Speed
# 0     77.00        4.70
# 1     97.00       12.75
# 2     62.01       17.22
# 3     70.25        3.56
# 4     57.99       26.40

# %%
weather_df.to_csv("Weather.csv")

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, 
#vmax=None, alpha=None, linewidths=None, verts=None, 
#edgecolors=None, *, plotnonfinite=False, data=None, **kwargs

fig,ax = plt.subplots(figsize = (10,8))



ax.scatter(weather_df["Lat"],weather_df["Max Temp"],c=weather_df['Max Temp'], cmap=plt.cm.coolwarm, s = 82);
ax.text(1,60,'EQUATOR', rotation=90, fontdict={"fontsize":8})
ax.vlines(0,20,110)
ax.set_ylim(20,110)

ax.set_title("City Latitude vs Max Temperature")
ax.set_xlabel("Latitudes", fontsize = 16);
ax.set_ylabel("Max Temperatures (°F)", fontsize = 16);

plt.savefig("images/LatVsTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig,ax = plt.subplots(figsize = (10,8))

ax.scatter(weather_df["Lat"],weather_df["Humidity"], s = 50,c="black");
ax.text(1,55,'EQUATOR', rotation=90, fontdict={"fontsize":8})
ax.vlines(0,-5,110)
ax.set_ylim(-5,105)

ax.set_title("City Latitude vs Humidity")
ax.set_xlabel("Latitudes", fontsize = 16);
ax.set_ylabel("Humidity", fontsize = 16);

plt.savefig("images/LatVsHumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig,ax = plt.subplots(figsize = (10,8))

ax.scatter(weather_df["Lat"],weather_df["Cloudiness"], s = 50, c="black");
ax.text(1,55,'EQUATOR', rotation=90, fontdict={"fontsize":8})
ax.vlines(0,-20,110)
ax.set_ylim(min(weather_df["Cloudiness"]-10),max(weather_df["Cloudiness"]+10))

ax.set_title("City Latitude vs Cloudiness")
ax.set_xlabel("Latitudes", fontsize = 16);
ax.set_ylabel("Cloudiness", fontsize = 16);

plt.savefig("images/LatVsCloudiness")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig,ax = plt.subplots(figsize = (10,8))

ax.scatter(weather_df["Lat"],weather_df["Wind Speed"], s = 50, c = "black");
ax.text(1,15,'EQUATOR', rotation=90, fontdict={"fontsize":8})
ax.vlines(0,-20,110)
ax.set_ylim(min(weather_df["Wind Speed"]-10),max(weather_df["Wind Speed"]+10))

ax.set_title("City Latitude vs Wind Speed")
ax.set_xlabel("Latitudes", fontsize = 16);
ax.set_ylabel("Wind Speed", fontsize = 16);

plt.savefig("images/LatVsWindSpeed.png")
