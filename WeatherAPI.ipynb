# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %%
city_ids = []
Cities = []
country = []
dates = []
clouds = []
humids = []
lats =[]
lngs = []
max_temps =[]
winds = []


cnt = 0
print("  Starting API Test Calls")
print("---------------------------")

for city in cities:
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&units=imperial&APPID={api_key}"
    url = requests.get(url).json()   
    cnt +=1
    print(f"Process #{cnt} for {city}.")
    try:   
        city_id = url["id"]
        city_ids.append(city_id)
        Cities.append(city.title())
        clouds.append(url["clouds"]["all"])
        country.append(url["sys"]["country"])
        date = int(url["dt"])
        date = datetime.utcfromtimestamp(date).strftime('%Y-%m-%d')
        dates.append(date)
        humids.append(url["main"]["humidity"])
        lats.append(url["coord"]["lat"])
        lngs.append(url["coord"]["lon"])
        max_temps.append(url["main"]["temp_max"])
        winds.append(url["wind"]["speed"])  
        print(f"Found: {city} with city id: {city_id}")
    except KeyError:
        print(f"{city} Not Found")
        pass
   
    
print("--------------")
print("  ALL DONE")
# Out:
#   Starting API Test Calls
# ---------------------------
# Process #1 for ushuaia.
# Found: ushuaia with city id: 3833367
# Process #2 for jamestown.
# Found: jamestown with city id: 2069194
# Process #3 for tuktoyaktuk.
# Found: tuktoyaktuk with city id: 6170031
# Process #4 for bredasdorp.
# Found: bredasdorp with city id: 1015776
# Process #5 for khatanga.
# Found: khatanga with city id: 2022572
# Process #6 for ixtapa.
# Found: ixtapa with city id: 4004293
# Process #7 for punta arenas.
# Found: punta arenas with city id: 3874787
# Process #8 for new norfolk.
# Found: new norfolk with city id: 2155415
# Process #9 for atuona.
# Found: atuona with city id: 4020109
# Process #10 for east london.
# Found: east london with city id: 1006984
# Process #11 for jumla.
# Found: jumla with city id: 1283285
# Process #12 for pangnirtung.
# Found: pangnirtung with city id: 6096551
# Process #13 for pankrushikha.
# Found: pankrushikha with city id: 1495613
# Process #14 for carnarvon.
# Found: carnarvon with city id: 1014034
# Process #15 for bluff.
# Found: bluff with city id: 2175403
# Process #16 for hasaki.
# Found: hasaki with city id: 2112802
# Process #17 for bambous virieux.
# Found: bambous virieux with city id: 1106677
# Process #18 for dikson.
# Found: dikson with city id: 1507390
# Process #19 for adrar.
# Found: adrar with city id: 2508813
# Process #20 for koulamoutou.
# Found: koulamoutou with city id: 2399959
# Process #21 for vostok.
# Found: vostok with city id: 2013279
# Process #22 for ayan.
# Found: ayan with city id: 749747
# Process #23 for aleksandrov gay.
# Found: aleksandrov gay with city id: 583345
# Process #24 for kolobovo.
# Found: kolobovo with city id: 546374
# Process #25 for ribeira grande.
# Found: ribeira grande with city id: 3372707
# Process #26 for ruatoria.
# ruatoria Not Found
# Process #27 for vao.
# Found: vao with city id: 588365
# Process #28 for tokonou.
# Found: tokonou with city id: 2414659
# Process #29 for samarai.
# Found: samarai with city id: 2132606
# Process #30 for albany.
# Found: albany with city id: 5106834
# Process #31 for doha.
# Found: doha with city id: 290030
# Process #32 for rikitea.
# Found: rikitea with city id: 4030556
# Process #33 for novyy urengoy.
# Found: novyy urengoy with city id: 1496511
# Process #34 for busselton.
# Found: busselton with city id: 2075265
# Process #35 for scunthorpe.
# Found: scunthorpe with city id: 2638324
# Process #36 for missoula.
# Found: missoula with city id: 5666639
# Process #37 for nalut.
# Found: nalut with city id: 2214433
# Process #38 for pulivendla.
# Found: pulivendla with city id: 1259264
# Process #39 for barrow.
# Found: barrow with city id: 3833859
# Process #40 for oriximina.
# Found: oriximina with city id: 3393471
# Process #41 for chokurdakh.
# Found: chokurdakh with city id: 2126123
# Process #42 for mataura.
# Found: mataura with city id: 6201424
# Process #43 for mahebourg.
# Found: mahebourg with city id: 934322
# Process #44 for saint-philippe.
# Found: saint-philippe with city id: 6138908
# Process #45 for aktash.
# aktash Not Found
# Process #46 for illoqqortoormiut.
# illoqqortoormiut Not Found
# Process #47 for rio grande.
# Found: rio grande with city id: 3451138
# Process #48 for kaupanger.
# Found: kaupanger with city id: 7288345
# Process #49 for samusu.
# samusu Not Found
# Process #50 for arraial do cabo.
# Found: arraial do cabo with city id: 3471451
# Process #51 for carauari.
# Found: carauari with city id: 3664659
# Process #52 for portland.
# Found: portland with city id: 5746545
# Process #53 for puerto ayora.
# Found: puerto ayora with city id: 3652764
# Process #54 for lata.
# Found: lata with city id: 1253628
# Process #55 for panuco.
# Found: panuco with city id: 3979844
# Process #56 for qaanaaq.
# Found: qaanaaq with city id: 3831208
# Process #57 for santa vitoria do palmar.
# Found: santa vitoria do palmar with city id: 3449747
# Process #58 for faanui.
# Found: faanui with city id: 4034551
# Process #59 for camocim.
# Found: camocim with city id: 3403687
# Process #60 for saint george.
# Found: saint george with city id: 262462
# Process #61 for tidore.
# tidore Not Found
# Process #62 for xinpu.
# Found: xinpu with city id: 1675151
# Process #63 for le mars.
# Found: le mars with city id: 4864337
# Process #64 for port-gentil.
# Found: port-gentil with city id: 2396518
# Process #65 for baruun-urt.
# Found: baruun-urt with city id: 2032614
# Process #66 for bilibino.
# Found: bilibino with city id: 2126682
# Process #67 for ancud.
# Found: ancud with city id: 3899695
# Process #68 for barra patuca.
# Found: barra patuca with city id: 3614835
# Process #69 for narsaq.
# Found: narsaq with city id: 3421719
# Process #70 for calvinia.
# Found: calvinia with city id: 3369174
# Process #71 for sokoni.
# Found: sokoni with city id: 901344
# Process #72 for beringovskiy.
# Found: beringovskiy with city id: 2126710
# Process #73 for porsa.
# Found: porsa with city id: 587620
# Process #74 for saskylakh.
# Found: saskylakh with city id: 2017155
# Process #75 for mocambique.
# mocambique Not Found
# Process #76 for kuytun.
# Found: kuytun with city id: 2021093
# Process #77 for nyurba.
# Found: nyurba with city id: 2018735
# Process #78 for teya.
# Found: teya with city id: 3526662
# Process #79 for neyshabur.
# Found: neyshabur with city id: 122285
# Process #80 for arkadelphia.
# Found: arkadelphia with city id: 4099647
# Process #81 for grand river south east.
# grand river south east Not Found
# Process #82 for nouadhibou.
# Found: nouadhibou with city id: 2377457
# Process #83 for atyrau.
# Found: atyrau with city id: 610529
# Process #84 for toliary.
# toliary Not Found
# Process #85 for butaritari.
# Found: butaritari with city id: 2110227
# Process #86 for vega de alatorre.
# Found: vega de alatorre with city id: 3514843
# Process #87 for lebu.
# Found: lebu with city id: 344979
# Process #88 for taolanaro.
# taolanaro Not Found
# Process #89 for naze.
# Found: naze with city id: 2337542
# Process #90 for hilo.
# Found: hilo with city id: 5855927
# Process #91 for souillac.
# Found: souillac with city id: 3026644
# Process #92 for port alfred.
# Found: port alfred with city id: 964432
# Process #93 for palabuhanratu.
# palabuhanratu Not Found
# Process #94 for san lawrenz.
# Found: san lawrenz with city id: 2562619
# Process #95 for karaul.
# karaul Not Found
# Process #96 for dzilam gonzalez.
# Found: dzilam gonzalez with city id: 3529654
# Process #97 for leh.
# Found: leh with city id: 1264976
# Process #98 for paamiut.
# Found: paamiut with city id: 3421193
# Process #99 for vaini.
# Found: vaini with city id: 1273574
# Process #100 for shimoda.
# Found: shimoda with city id: 1852357
# Process #101 for werda.
# Found: werda with city id: 2810970
# Process #102 for georgetown.
# Found: georgetown with city id: 3378644
# Process #103 for khuzdar.
# Found: khuzdar with city id: 7082481
# Process #104 for nanortalik.
# Found: nanortalik with city id: 3421765
# Process #105 for labuhan.
# Found: labuhan with city id: 1641899
# Process #106 for hurricane.
# Found: hurricane with city id: 5540831
# Process #107 for hobart.
# Found: hobart with city id: 2163355
# Process #108 for ryotsu.
# Found: ryotsu with city id: 1853371
# Process #109 for isangel.
# Found: isangel with city id: 2136825
# Process #110 for makakilo city.
# Found: makakilo city with city id: 5850554
# Process #111 for victoria.
# Found: victoria with city id: 1733782
# Process #112 for castro.
# Found: castro with city id: 3896218
# Process #113 for richards bay.
# Found: richards bay with city id: 962367
# Process #114 for hami.
# Found: hami with city id: 1529484
# Process #115 for sibolga.
# Found: sibolga with city id: 1213855
# Process #116 for kutum.
# Found: kutum with city id: 371745
# Process #117 for itarema.
# Found: itarema with city id: 3393692
# Process #118 for wanlaweyn.
# Found: wanlaweyn with city id: 50672
# Process #119 for aklavik.
# Found: aklavik with city id: 5882953
# Process #120 for broome.
# Found: broome with city id: 2656067
# Process #121 for raglan.
# Found: raglan with city id: 2183854
# Process #122 for tsihombe.
# tsihombe Not Found
# Process #123 for isla mujeres.
# Found: isla mujeres with city id: 3526756
# Process #124 for vila franca do campo.
# Found: vila franca do campo with city id: 3372472
# Process #125 for loreto.
# Found: loreto with city id: 3438834
# Process #126 for yellowknife.
# Found: yellowknife with city id: 6185377
# Process #127 for sinjah.
# sinjah Not Found
# Process #128 for umzimvubu.
# umzimvubu Not Found
# Process #129 for axim.
# Found: axim with city id: 2303611
# Process #130 for san patricio.
# Found: san patricio with city id: 3437029
# Process #131 for vaitupu.
# vaitupu Not Found
# Process #132 for cherskiy.
# Found: cherskiy with city id: 2126199
# Process #133 for saint-pierre.
# Found: saint-pierre with city id: 2995603
# Process #134 for ucluelet.
# Found: ucluelet with city id: 6171633
# Process #135 for sechura.
# Found: sechura with city id: 3691954
# Process #136 for port elizabeth.
# Found: port elizabeth with city id: 4501427
# Process #137 for ketchikan.
# Found: ketchikan with city id: 5554428
# Process #138 for villarrica.
# Found: villarrica with city id: 3868158
# Process #139 for kuah.
# kuah Not Found
# Process #140 for lolua.
# lolua Not Found
# Process #141 for cape town.
# Found: cape town with city id: 3369157
# Process #142 for katsuura.
# Found: katsuura with city id: 1865309
# Process #143 for broken hill.
# Found: broken hill with city id: 2173911
# Process #144 for tiksi.
# Found: tiksi with city id: 2015306
# Process #145 for brawley.
# Found: brawley with city id: 5330567
# Process #146 for caravelas.
# Found: caravelas with city id: 3466980
# Process #147 for amderma.
# amderma Not Found
# Process #148 for fuerte olimpo.
# Found: fuerte olimpo with city id: 3438102
# Process #149 for darhan.
# Found: darhan with city id: 2031964
# Process #150 for yanan.
# yanan Not Found
# Process #151 for mehamn.
# Found: mehamn with city id: 778707
# Process #152 for marawi.
# Found: marawi with city id: 1701054
# Process #153 for petatlan.
# Found: petatlan with city id: 3992842
# Process #154 for makung.
# makung Not Found
# Process #155 for kodiak.
# Found: kodiak with city id: 4407665
# Process #156 for saleaula.
# saleaula Not Found
# Process #157 for rosiile.
# Found: rosiile with city id: 668628
# Process #158 for chissamba.
# chissamba Not Found
# Process #159 for mayumba.
# Found: mayumba with city id: 2399001
# Process #160 for coroico.
# Found: coroico with city id: 3919085
# Process #161 for tasiilaq.
# Found: tasiilaq with city id: 3424607
# Process #162 for batemans bay.
# Found: batemans bay with city id: 2176639
# Process #163 for acari.
# Found: acari with city id: 3390864
# Process #164 for ondo.
# Found: ondo with city id: 2326171
# Process #165 for padang.
# Found: padang with city id: 1633419
# Process #166 for vila velha.
# Found: vila velha with city id: 6320062
# Process #167 for sao gabriel da cachoeira.
# Found: sao gabriel da cachoeira with city id: 3662342
# Process #168 for barentsburg.
# barentsburg Not Found
# Process #169 for constantine.
# Found: constantine with city id: 2501152
# Process #170 for klaksvik.
# Found: klaksvik with city id: 2618795
# Process #171 for belmonte.
# Found: belmonte with city id: 8010472
# Process #172 for birobidzhan.
# Found: birobidzhan with city id: 2026643
# Process #173 for manta.
# Found: manta with city id: 685981
# Process #174 for omboue.
# Found: omboue with city id: 2396853
# Process #175 for tuatapere.
# Found: tuatapere with city id: 2180815
# Process #176 for kruisfontein.
# Found: kruisfontein with city id: 986717
# Process #177 for nikolskoye.
# Found: nikolskoye with city id: 546105
# Process #178 for upernavik.
# Found: upernavik with city id: 3418910
# Process #179 for palamos.
# Found: palamos with city id: 3114566
# Process #180 for geraldton.
# Found: geraldton with city id: 5960603
# Process #181 for kurilsk.
# Found: kurilsk with city id: 2123979
# Process #182 for batouri.
# Found: batouri with city id: 2234663
# Process #183 for bayir.
# Found: bayir with city id: 304183
# Process #184 for hithadhoo.
# Found: hithadhoo with city id: 1282256
# Process #185 for matagami.
# Found: matagami with city id: 2335713
# Process #186 for virginia beach.
# Found: virginia beach with city id: 4791259
# Process #187 for kavieng.
# Found: kavieng with city id: 2094342
# Process #188 for labutta.
# labutta Not Found
# Process #189 for bethel.
# Found: bethel with city id: 5880568
# Process #190 for hamilton.
# Found: hamilton with city id: 3573197
# Process #191 for severo-kurilsk.
# Found: severo-kurilsk with city id: 2121385
# Process #192 for belushya guba.
# belushya guba Not Found
# Process #193 for hermanus.
# Found: hermanus with city id: 3366880
# Process #194 for mar del plata.
# Found: mar del plata with city id: 3863379
# Process #195 for kapaa.
# Found: kapaa with city id: 5848280
# Process #196 for comodoro rivadavia.
# Found: comodoro rivadavia with city id: 3860443
# Process #197 for fairbanks.
# Found: fairbanks with city id: 5861897
# Process #198 for tautira.
# Found: tautira with city id: 4033557
# Process #199 for la palma.
# Found: la palma with city id: 3687505
# Process #200 for kollam.
# Found: kollam with city id: 1259091
# Process #201 for the valley.
# Found: the valley with city id: 3573374
# Process #202 for traverse city.
# Found: traverse city with city id: 5012495
# Process #203 for mahibadhoo.
# Found: mahibadhoo with city id: 1337605
# Process #204 for pumiao.
# Found: pumiao with city id: 1798480
# Process #205 for hobyo.
# Found: hobyo with city id: 57000
# Process #206 for kaitangata.
# Found: kaitangata with city id: 2208248
# Process #207 for sentyabrskiy.
# sentyabrskiy Not Found
# Process #208 for san jeronimo.
# Found: san jeronimo with city id: 3929607
# Process #209 for colares.
# Found: colares with city id: 2269142
# Process #210 for bageshwar.
# Found: bageshwar with city id: 1277907
# Process #211 for cairns.
# Found: cairns with city id: 2172797
# Process #212 for clyde river.
# Found: clyde river with city id: 5924351
# Process #213 for makokou.
# Found: makokou with city id: 2399371
# Process #214 for kiunga.
# Found: kiunga with city id: 2093846
# Process #215 for bonnyville.
# Found: bonnyville with city id: 5905616
# Process #216 for oussouye.
# Found: oussouye with city id: 2246901
# Process #217 for mys shmidta.
# mys shmidta Not Found
# Process #218 for saldanha.
# Found: saldanha with city id: 2737599
# Process #219 for avarua.
# Found: avarua with city id: 4035715
# Process #220 for anadyr.
# Found: anadyr with city id: 2127202
# Process #221 for gwadar.
# Found: gwadar with city id: 1177446
# Process #222 for talnakh.
# Found: talnakh with city id: 1490256
# Process #223 for lazaro cardenas.
# Found: lazaro cardenas with city id: 3996234
# Process #224 for bowen.
# Found: bowen with city id: 2174444
# Process #225 for acapulco.
# Found: acapulco with city id: 3533462
# Process #226 for dingle.
# Found: dingle with city id: 1714733
# Process #227 for tabou.
# Found: tabou with city id: 2281120
# Process #228 for volksrust.
# Found: volksrust with city id: 943032
# Process #229 for zabid.
# Found: zabid with city id: 69559
# Process #230 for vikulovo.
# Found: vikulovo with city id: 557754
# Process #231 for yantal.
# Found: yantal with city id: 2055868
# Process #232 for nome.
# Found: nome with city id: 4732862
# Process #233 for washougal.
# Found: washougal with city id: 5815136
# Process #234 for kysyl-syr.
# Found: kysyl-syr with city id: 2021017
# Process #235 for henties bay.
# Found: henties bay with city id: 3356832
# Process #236 for marathon.
# Found: marathon with city id: 6065867
# Process #237 for noshiro.
# Found: noshiro with city id: 2128867
# Process #238 for lasa.
# Found: lasa with city id: 146639
# Process #239 for kiruna.
# Found: kiruna with city id: 605155
# Process #240 for bo phloi.
# Found: bo phloi with city id: 1153850
# Process #241 for kawana waters.
# kawana waters Not Found
# Process #242 for ponta do sol.
# Found: ponta do sol with city id: 3453439
# Process #243 for san quintin.
# Found: san quintin with city id: 1688687
# Process #244 for vieques.
# Found: vieques with city id: 4568570
# Process #245 for masaka.
# Found: masaka with city id: 229380
# Process #246 for sapele.
# Found: sapele with city id: 2323675
# Process #247 for lagoa.
# Found: lagoa with city id: 2267254
# Process #248 for oktyabrskoye.
# Found: oktyabrskoye with city id: 1511846
# Process #249 for vardo.
# Found: vardo with city id: 4372777
# Process #250 for flin flon.
# Found: flin flon with city id: 5954718
# Process #251 for carutapera.
# Found: carutapera with city id: 3402648
# Process #252 for puerto suarez.
# Found: puerto suarez with city id: 3465342
# Process #253 for luderitz.
# Found: luderitz with city id: 3355672
# Process #254 for nhulunbuy.
# Found: nhulunbuy with city id: 2064735
# Process #255 for vilhena.
# Found: vilhena with city id: 3924679
# Process #256 for provideniya.
# Found: provideniya with city id: 4031574
# Process #257 for luau.
# Found: luau with city id: 876177
# Process #258 for cabo san lucas.
# Found: cabo san lucas with city id: 3985710
# Process #259 for komsomolskiy.
# Found: komsomolskiy with city id: 1486910
# Process #260 for duliagaon.
# Found: duliagaon with city id: 1272259
# Process #261 for turukhansk.
# Found: turukhansk with city id: 1488903
# Process #262 for zhigalovo.
# Found: zhigalovo with city id: 2012532
# Process #263 for san carlos de bariloche.
# Found: san carlos de bariloche with city id: 7647007
# Process #264 for liverpool.
# Found: liverpool with city id: 2644210
# Process #265 for tessalit.
# Found: tessalit with city id: 2449893
# Process #266 for corn island.
# Found: corn island with city id: 3620266
# Process #267 for kieta.
# Found: kieta with city id: 2094027
# Process #268 for maradi.
# Found: maradi with city id: 2441291
# Process #269 for brae.
# Found: brae with city id: 2654970
# Process #270 for russellville.
# Found: russellville with city id: 4129397
# Process #271 for longyearbyen.
# Found: longyearbyen with city id: 2729907
# Process #272 for otukpo.
# Found: otukpo with city id: 2328113
# Process #273 for attawapiskat.
# attawapiskat Not Found
# Process #274 for tumannyy.
# tumannyy Not Found
# Process #275 for areka.
# Found: areka with city id: 343593
# Process #276 for mayo.
# Found: mayo with city id: 6068416
# Process #277 for avera.
# Found: avera with city id: 4231997
# Process #278 for bengkulu.
# bengkulu Not Found
# Process #279 for bourg-en-bresse.
# Found: bourg-en-bresse with city id: 3031009
# Process #280 for bull savanna.
# Found: bull savanna with city id: 3491161
# Process #281 for cayenne.
# Found: cayenne with city id: 3382160
# Process #282 for dunedin.
# Found: dunedin with city id: 2191562
# Process #283 for norman wells.
# Found: norman wells with city id: 6089245
# Process #284 for pasni.
# Found: pasni with city id: 1168312
# Process #285 for olafsvik.
# olafsvik Not Found
# Process #286 for samalaeulu.
# samalaeulu Not Found
# Process #287 for pangody.
# Found: pangody with city id: 1495626
# Process #288 for hastings.
# Found: hastings with city id: 2190224
# Process #289 for ambanja.
# Found: ambanja with city id: 1083724
# Process #290 for grants.
# Found: grants with city id: 5469841
# Process #291 for jorpeland.
# Found: jorpeland with city id: 3150742
# Process #292 for alpena.
# Found: alpena with city id: 4984075
# Process #293 for sorvag.
# sorvag Not Found
# Process #294 for mantua.
# Found: mantua with city id: 3174050
# Process #295 for chuy.
# Found: chuy with city id: 3443061
# Process #296 for balkanabat.
# Found: balkanabat with city id: 161616
# Process #297 for kudat.
# Found: kudat with city id: 1736458
# Process #298 for torbay.
# Found: torbay with city id: 6167817
# Process #299 for bhilwara.
# Found: bhilwara with city id: 1275960
# Process #300 for lorengau.
# Found: lorengau with city id: 2092164
# Process #301 for viesite.
# Found: viesite with city id: 454216
# Process #302 for aykhal.
# Found: aykhal with city id: 2027296
# Process #303 for faratsiho.
# Found: faratsiho with city id: 1065140
# Process #304 for sarkand.
# Found: sarkand with city id: 1519691
# Process #305 for baiyin.
# Found: baiyin with city id: 1817240
# Process #306 for barmer.
# Found: barmer with city id: 1276901
# Process #307 for kiama.
# Found: kiama with city id: 2161515
# Process #308 for kalemie.
# Found: kalemie with city id: 214974
# Process #309 for yuksekova.
# Found: yuksekova with city id: 296173
# Process #310 for nishihara.
# Found: nishihara with city id: 1850144
# Process #311 for sayansk.
# Found: sayansk with city id: 2055166
# Process #312 for adre.
# Found: adre with city id: 245669
# Process #313 for gamba.
# Found: gamba with city id: 1281256
# Process #314 for ayaviri.
# Found: ayaviri with city id: 3946985
# Process #315 for datong.
# Found: datong with city id: 2037799
# Process #316 for berlevag.
# Found: berlevag with city id: 780687
# Process #317 for lahad datu.
# Found: lahad datu with city id: 1733953
# Process #318 for ingham.
# Found: ingham with city id: 2162737
# Process #319 for ananas.
# Found: ananas with city id: 3723841
# Process #320 for wahran.
# wahran Not Found
# Process #321 for puerto del rosario.
# Found: puerto del rosario with city id: 2512186
# Process #322 for espanola.
# Found: espanola with city id: 5949493
# Process #323 for belaya gora.
# Found: belaya gora with city id: 2126785
# Process #324 for port blair.
# Found: port blair with city id: 1259385
# Process #325 for chipinge.
# Found: chipinge with city id: 893549
# Process #326 for pyaozerskiy.
# Found: pyaozerskiy with city id: 503581
# Process #327 for puerto escondido.
# Found: puerto escondido with city id: 3520994
# Process #328 for huarmey.
# Found: huarmey with city id: 3939168
# Process #329 for sapa.
# Found: sapa with city id: 1715430
# Process #330 for bayeux.
# Found: bayeux with city id: 3034483
# Process #331 for znamenskoye.
# Found: znamenskoye with city id: 1485020
# Process #332 for mount gambier.
# Found: mount gambier with city id: 2156643
# Process #333 for warqla.
# warqla Not Found
# Process #334 for korla.
# korla Not Found
# Process #335 for harper.
# Found: harper with city id: 4696310
# Process #336 for shakawe.
# Found: shakawe with city id: 933077
# Process #337 for sao filipe.
# Found: sao filipe with city id: 3374210
# Process #338 for synya.
# Found: synya with city id: 485215
# Process #339 for alpine.
# Found: alpine with city id: 4998005
# Process #340 for puerto baquerizo moreno.
# Found: puerto baquerizo moreno with city id: 3652758
# Process #341 for alyangula.
# Found: alyangula with city id: 2079582
# Process #342 for karratha.
# Found: karratha with city id: 6620339
# Process #343 for muzhi.
# Found: muzhi with city id: 1498161
# Process #344 for nuuk.
# Found: nuuk with city id: 3421319
# Process #345 for cidreira.
# Found: cidreira with city id: 3466165
# Process #346 for cardston.
# Found: cardston with city id: 5916821
# Process #347 for pochutla.
# Found: pochutla with city id: 3517970
# Process #348 for maldonado.
# Found: maldonado with city id: 3441894
# Process #349 for luena.
# Found: luena with city id: 3347719
# Process #350 for sanski most.
# Found: sanski most with city id: 3191297
# Process #351 for aswan.
# Found: aswan with city id: 359792
# Process #352 for meridian.
# Found: meridian with city id: 4435764
# Process #353 for thompson.
# Found: thompson with city id: 6165406
# Process #354 for dongsheng.
# Found: dongsheng with city id: 1788268
# Process #355 for iqaluit.
# Found: iqaluit with city id: 5983720
# Process #356 for lavrentiya.
# Found: lavrentiya with city id: 4031637
# Process #357 for suzun.
# Found: suzun with city id: 1490551
# Process #358 for vanavara.
# Found: vanavara with city id: 2013727
# Process #359 for valparaiso.
# Found: valparaiso with city id: 4927537
# Process #360 for torbeyevo.
# Found: torbeyevo with city id: 482123
# Process #361 for shache.
# Found: shache with city id: 1280037
# Process #362 for puerto carreno.
# Found: puerto carreno with city id: 3671519
# Process #363 for urumqi.
# urumqi Not Found
# Process #364 for tazovskiy.
# Found: tazovskiy with city id: 1489853
# Process #365 for ygatimi.
# Found: ygatimi with city id: 3436616
# Process #366 for bubaque.
# Found: bubaque with city id: 2374583
# Process #367 for seminole.
# Found: seminole with city id: 5530452
# Process #368 for rauma.
# Found: rauma with city id: 639735
# Process #369 for muriwai beach.
# Found: muriwai beach with city id: 2186363
# Process #370 for estelle.
# Found: estelle with city id: 4671240
# Process #371 for constitucion.
# Found: constitucion with city id: 4011743
# Process #372 for deloraine.
# Found: deloraine with city id: 5937577
# Process #373 for newport.
# Found: newport with city id: 2641598
# Process #374 for sitka.
# Found: sitka with city id: 4267710
# Process #375 for kuche.
# kuche Not Found
# Process #376 for vigrestad.
# Found: vigrestad with city id: 3131824
# Process #377 for nerchinsk.
# Found: nerchinsk with city id: 2019326
# Process #378 for kontagora.
# Found: kontagora with city id: 2334008
# Process #379 for plouzane.
# Found: plouzane with city id: 2986626
# Process #380 for linxia.
# Found: linxia with city id: 1803331
# Process #381 for touros.
# Found: touros with city id: 3386213
# Process #382 for kuruman.
# Found: kuruman with city id: 986134
# Process #383 for sao jose da coroa grande.
# Found: sao jose da coroa grande with city id: 3388456
# Process #384 for erenhot.
# Found: erenhot with city id: 2037485
# Process #385 for oktyabrskiy.
# Found: oktyabrskiy with city id: 515873
# Process #386 for kemi.
# Found: kemi with city id: 653281
# Process #387 for sandovo.
# Found: sandovo with city id: 498856
# Process #388 for esperance.
# Found: esperance with city id: 3573739
# Process #389 for celano.
# Found: celano with city id: 3179216
# Process #390 for tongzhou.
# Found: tongzhou with city id: 1799722
# Process #391 for garowe.
# Found: garowe with city id: 58933
# Process #392 for alofi.
# Found: alofi with city id: 4036284
# Process #393 for pisco.
# Found: pisco with city id: 3932145
# Process #394 for floridablanca.
# Found: floridablanca with city id: 1713601
# Process #395 for nizhneyansk.
# nizhneyansk Not Found
# Process #396 for mao.
# Found: mao with city id: 3496831
# Process #397 for bargal.
# bargal Not Found
# Process #398 for dajal.
# Found: dajal with city id: 1180752
# Process #399 for cockburn town.
# Found: cockburn town with city id: 3576994
# Process #400 for ponta delgada.
# Found: ponta delgada with city id: 3372783
# Process #401 for ossora.
# Found: ossora with city id: 2122389
# Process #402 for grand gaube.
# Found: grand gaube with city id: 934479
# Process #403 for bolungarvik.
# bolungarvik Not Found
# Process #404 for trapani.
# Found: trapani with city id: 6542155
# Process #405 for liancheng.
# Found: liancheng with city id: 1804119
# Process #406 for mattru.
# Found: mattru with city id: 2409215
# Process #407 for codrington.
# Found: codrington with city id: 2160063
# Process #408 for pevek.
# Found: pevek with city id: 2122090
# Process #409 for meadow lake.
# Found: meadow lake with city id: 6071421
# Process #410 for udachnyy.
# Found: udachnyy with city id: 2014624
# Process #411 for berdigestyakh.
# Found: berdigestyakh with city id: 2026861
# Process #412 for sorland.
# Found: sorland with city id: 3137469
# Process #413 for todos santos.
# Found: todos santos with city id: 3981432
# Process #414 for darnah.
# Found: darnah with city id: 87205
# Process #415 for debre birhan.
# Found: debre birhan with city id: 339734
# Process #416 for suao.
# suao Not Found
# Process #417 for bandarbeyla.
# Found: bandarbeyla with city id: 64814
# Process #418 for hofn.
# Found: hofn with city id: 2630299
# Process #419 for auki.
# Found: auki with city id: 2339937
# Process #420 for kosugi.
# Found: kosugi with city id: 1858695
# Process #421 for havelock.
# Found: havelock with city id: 4470244
# Process #422 for manakara.
# Found: manakara with city id: 1061605
# Process #423 for mailsi.
# Found: mailsi with city id: 1171502
# Process #424 for chumikan.
# Found: chumikan with city id: 2025256
# Process #425 for nianzishan.
# Found: nianzishan with city id: 2035593
# Process #426 for arlit.
# Found: arlit with city id: 2447513
# Process #427 for itoman.
# Found: itoman with city id: 1861280
# Process #428 for ca mau.
# Found: ca mau with city id: 1586443
# Process #429 for zernograd.
# Found: zernograd with city id: 463637
# Process #430 for ulaangom.
# Found: ulaangom with city id: 1515029
# Process #431 for ostrovnoy.
# Found: ostrovnoy with city id: 556268
# Process #432 for pontianak.
# Found: pontianak with city id: 1630789
# Process #433 for mitu.
# Found: mitu with city id: 117392
# Process #434 for aksarayskiy.
# Found: aksarayskiy with city id: 583683
# Process #435 for kibala.
# Found: kibala with city id: 2425791
# Process #436 for soria.
# Found: soria with city id: 3108681
# Process #437 for rondonopolis.
# Found: rondonopolis with city id: 3450909
# Process #438 for uniara.
# uniara Not Found
# Process #439 for la ronge.
# Found: la ronge with city id: 6050066
# Process #440 for jinhua.
# Found: jinhua with city id: 1805528
# Process #441 for yanam.
# Found: yanam with city id: 1252795
# Process #442 for pueblo.
# Found: pueblo with city id: 5435464
# Process #443 for pomabamba.
# Found: pomabamba with city id: 3693468
# Process #444 for palauig.
# Found: palauig with city id: 1696188
# Process #445 for ilulissat.
# Found: ilulissat with city id: 3423146
# Process #446 for amot.
# Found: amot with city id: 3163198
# Process #447 for labuan.
# Found: labuan with city id: 1733782
# Process #448 for banda aceh.
# Found: banda aceh with city id: 1215502
# Process #449 for guerrero negro.
# Found: guerrero negro with city id: 4021858
# Process #450 for imbituba.
# Found: imbituba with city id: 3461370
# Process #451 for moranbah.
# Found: moranbah with city id: 6533368
# Process #452 for yichun.
# Found: yichun with city id: 2033413
# Process #453 for labe.
# Found: labe with city id: 2331140
# Process #454 for macenta.
# Found: macenta with city id: 2417988
# Process #455 for taft.
# Found: taft with city id: 1684659
# Process #456 for coihaique.
# Found: coihaique with city id: 3894426
# Process #457 for rio cuarto.
# Found: rio cuarto with city id: 3838874
# Process #458 for chaa-khol.
# chaa-khol Not Found
# Process #459 for gizo.
# Found: gizo with city id: 6693679
# Process #460 for dosso.
# Found: dosso with city id: 2445488
# Process #461 for marzuq.
# Found: marzuq with city id: 72181
# Process #462 for raga.
# raga Not Found
# Process #463 for maceio.
# Found: maceio with city id: 3395981
# Process #464 for mlonggo.
# Found: mlonggo with city id: 1635164
# Process #465 for malakal.
# malakal Not Found
# Process #466 for sal rei.
# Found: sal rei with city id: 3374235
# Process #467 for biu.
# Found: biu with city id: 2346995
# Process #468 for matola.
# Found: matola with city id: 1039854
# Process #469 for rocha.
# Found: rocha with city id: 3440777
# Process #470 for sohag.
# Found: sohag with city id: 347796
# Process #471 for taszar.
# Found: taszar with city id: 3044088
# Process #472 for alexandria.
# Found: alexandria with city id: 4314550
# Process #473 for san cristobal.
# Found: san cristobal with city id: 3652462
# Process #474 for san blas.
# Found: san blas with city id: 3987544
# Process #475 for saint-denis.
# Found: saint-denis with city id: 2980916
# Process #476 for grindavik.
# Found: grindavik with city id: 3416888
# Process #477 for rio brilhante.
# Found: rio brilhante with city id: 3451241
# Process #478 for lusambo.
# Found: lusambo with city id: 210379
# Process #479 for bajo baudo.
# bajo baudo Not Found
# Process #480 for port lincoln.
# Found: port lincoln with city id: 2063036
# Process #481 for balikpapan.
# Found: balikpapan with city id: 1650527
# Process #482 for mount isa.
# Found: mount isa with city id: 2065594
# Process #483 for leningradskiy.
# Found: leningradskiy with city id: 2123814
# Process #484 for cookeville.
# Found: cookeville with city id: 4615145
# Process #485 for airai.
# Found: airai with city id: 1651810
# Process #486 for zhigansk.
# Found: zhigansk with city id: 2012530
# Process #487 for jiexiu.
# Found: jiexiu with city id: 1805833
# Process #488 for saint-joseph.
# Found: saint-joseph with city id: 3037456
# Process #489 for dukat.
# Found: dukat with city id: 786562
# Process #490 for gabu.
# Found: gabu with city id: 1791785
# Process #491 for kourou.
# Found: kourou with city id: 3381303
# Process #492 for hambantota.
# Found: hambantota with city id: 1244926
# Process #493 for zhezkazgan.
# Found: zhezkazgan with city id: 1516589
# Process #494 for sao francisco.
# Found: sao francisco with city id: 3467400
# Process #495 for sobolevo.
# Found: sobolevo with city id: 525426
# Process #496 for xiaoweizhai.
# Found: xiaoweizhai with city id: 1789945
# Process #497 for kamuli.
# Found: kamuli with city id: 232397
# Process #498 for astana.
# Found: astana with city id: 1526273
# Process #499 for manjacaze.
# Found: manjacaze with city id: 1040938
# Process #500 for igede.
# Found: igede with city id: 2328925
# Process #501 for saint-augustin.
# Found: saint-augustin with city id: 3031582
# Process #502 for seymchan.
# Found: seymchan with city id: 2121373
# Process #503 for tirumullaivasal.
# Found: tirumullaivasal with city id: 1254367
# Process #504 for nantucket.
# Found: nantucket with city id: 4944903
# Process #505 for umm bab.
# Found: umm bab with city id: 289548
# Process #506 for yialos.
# yialos Not Found
# Process #507 for okhotsk.
# Found: okhotsk with city id: 2122605
# Process #508 for namatanai.
# Found: namatanai with city id: 2090021
# Process #509 for praya.
# Found: praya with city id: 1630662
# Process #510 for tieli.
# Found: tieli with city id: 2034440
# Process #511 for najran.
# Found: najran with city id: 103630
# Process #512 for byron bay.
# Found: byron bay with city id: 2172880
# Process #513 for cavalcante.
# Found: cavalcante with city id: 3466594
# Process #514 for neepawa.
# Found: neepawa with city id: 6086673
# Process #515 for champerico.
# Found: champerico with city id: 3530097
# Process #516 for rapid city.
# Found: rapid city with city id: 5768233
# Process #517 for altamira.
# Found: altamira with city id: 3407882
# Process #518 for alakurtti.
# Found: alakurtti with city id: 583472
# Process #519 for artyk.
# artyk Not Found
# Process #520 for mana.
# Found: mana with city id: 789988
# Process #521 for mitha tiwana.
# Found: mitha tiwana with city id: 1170222
# Process #522 for kupang.
# Found: kupang with city id: 2057087
# Process #523 for jardim.
# Found: jardim with city id: 3460087
# Process #524 for te anau.
# Found: te anau with city id: 2181625
# Process #525 for bilma.
# Found: bilma with city id: 2446796
# Process #526 for chateauroux.
# Found: chateauroux with city id: 3016194
# Process #527 for fort nelson.
# Found: fort nelson with city id: 5955902
# Process #528 for namibe.
# Found: namibe with city id: 3347019
# Process #529 for cam pha.
# cam pha Not Found
# Process #530 for upata.
# Found: upata with city id: 3625710
# Process #531 for tual.
# Found: tual with city id: 1623197
# Process #532 for shimonoseki.
# Found: shimonoseki with city id: 1852225
# Process #533 for limbang.
# Found: limbang with city id: 1737714
# Process #534 for vestmanna.
# Found: vestmanna with city id: 2610343
# Process #535 for shahr-e babak.
# Found: shahr-e babak with city id: 115781
# Process #536 for dondo.
# Found: dondo with city id: 1024696
# Process #537 for frontera.
# Found: frontera with city id: 3527545
# Process #538 for zaysan.
# Found: zaysan with city id: 1517060
# Process #539 for angra.
# angra Not Found
# Process #540 for hailar.
# Found: hailar with city id: 2037078
# Process #541 for turayf.
# Found: turayf with city id: 101312
# Process #542 for shizilu.
# Found: shizilu with city id: 1893334
# Process #543 for qaqortoq.
# Found: qaqortoq with city id: 3420846
# Process #544 for gornozavodsk.
# Found: gornozavodsk with city id: 559752
# Process #545 for amapa.
# Found: amapa with city id: 3603330
# Process #546 for francistown.
# Found: francistown with city id: 933778
# Process #547 for tezu.
# Found: tezu with city id: 1254709
# Process #548 for bizhbulyak.
# Found: bizhbulyak with city id: 576195
# Process #549 for sadon.
# Found: sadon with city id: 525990
# Process #550 for herat.
# Found: herat with city id: 1140026
# Process #551 for honiara.
# Found: honiara with city id: 2108502
# Process #552 for paita.
# Found: paita with city id: 3694112
# Process #553 for veletma.
# veletma Not Found
# Process #554 for yambio.
# yambio Not Found
# Process #555 for luancheng.
# Found: luancheng with city id: 1802204
# Process #556 for tarko-sale.
# Found: tarko-sale with city id: 1490085
# Process #557 for mound.
# Found: mound with city id: 5038348
# Process #558 for kismayo.
# kismayo Not Found
# Process #559 for sioux lookout.
# Found: sioux lookout with city id: 6148373
# Process #560 for aleksandrovskiy zavod.
# Found: aleksandrovskiy zavod with city id: 2027933
# Process #561 for beloha.
# Found: beloha with city id: 1067565
# Process #562 for sao joao da barra.
# Found: sao joao da barra with city id: 3448903
# Process #563 for pouebo.
# Found: pouebo with city id: 2138607
# Process #564 for los llanos de aridane.
# Found: los llanos de aridane with city id: 2514651
# Process #565 for utiroa.
# utiroa Not Found
# Process #566 for ciudad bolivar.
# Found: ciudad bolivar with city id: 3645532
# Process #567 for flinders.
# Found: flinders with city id: 6255012
# Process #568 for koygorodok.
# Found: koygorodok with city id: 543396
# Process #569 for wenatchee.
# Found: wenatchee with city id: 5815342
# Process #570 for cazaje.
# cazaje Not Found
# Process #571 for yarmouth.
# Found: yarmouth with city id: 2633414
# Process #572 for maneadero.
# maneadero Not Found
# Process #573 for shelburne.
# Found: shelburne with city id: 6145890
# Process #574 for ballybofey.
# Found: ballybofey with city id: 2966668
# Process #575 for lodja.
# Found: lodja with city id: 211647
# Process #576 for knysna.
# Found: knysna with city id: 988698
# Process #577 for eureka.
# Found: eureka with city id: 5563397
# Process #578 for chihuahua.
# Found: chihuahua with city id: 4014338
# Process #579 for reggio di calabria.
# Found: reggio di calabria with city id: 6542287
# Process #580 for milkovo.
# Found: milkovo with city id: 727030
# Process #581 for bathsheba.
# Found: bathsheba with city id: 3374083
# Process #582 for chara.
# Found: chara with city id: 262462
# Process #583 for outjo.
# Found: outjo with city id: 3353715
# Process #584 for valdivia.
# Found: valdivia with city id: 3868707
# Process #585 for seoul.
# Found: seoul with city id: 1835848
# Process #586 for ulladulla.
# Found: ulladulla with city id: 2145554
# Process #587 for kroya.
# Found: kroya with city id: 7870153
# Process #588 for marsh harbour.
# Found: marsh harbour with city id: 3571913
# Process #589 for halifax.
# Found: halifax with city id: 6324729
# Process #590 for nioro.
# Found: nioro with city id: 2413070
# Process #591 for port hedland.
# Found: port hedland with city id: 2063042
# Process #592 for pozo colorado.
# Found: pozo colorado with city id: 3437443
# Process #593 for kijang.
# Found: kijang with city id: 1842966
# Process #594 for mizdah.
# Found: mizdah with city id: 2214827
# Process #595 for marietta.
# Found: marietta with city id: 4207783
# Process #596 for soyo.
# Found: soyo with city id: 2236967
# Process #597 for lillooet.
# Found: lillooet with city id: 6945979
# Process #598 for yumen.
# Found: yumen with city id: 1528998
# Process #599 for dwarka.
# Found: dwarka with city id: 1273294
# Process #600 for san fernando.
# Found: san fernando with city id: 3573739
# Process #601 for zyryanka.
# Found: zyryanka with city id: 2119283
# Process #602 for oil city.
# Found: oil city with city id: 5204278
# Process #603 for socorro.
# Found: socorro with city id: 1685936
# Process #604 for nizhniye sergi.
# Found: nizhniye sergi with city id: 520667
# Process #605 for aden.
# Found: aden with city id: 415189
# Process #606 for salalah.
# Found: salalah with city id: 286621
# Process #607 for saint anthony.
# Found: saint anthony with city id: 5606187
# Process #608 for coahuayana.
# Found: coahuayana with city id: 3981460
# Process #609 for honolulu.
# Found: honolulu with city id: 5856195
# Process #610 for jizan.
# Found: jizan with city id: 105299
# Process #611 for ilinskiy.
# Found: ilinskiy with city id: 557140
# Process #612 for vernon.
# Found: vernon with city id: 6173864
# Process #613 for aripuana.
# Found: aripuana with city id: 3665202
# Process #614 for opuwo.
# Found: opuwo with city id: 3354077
# Process #615 for kentville.
# Found: kentville with city id: 5991148
# Process #616 for laguna.
# Found: laguna with city id: 4013704
# Process #617 for bintulu.
# Found: bintulu with city id: 1737486
# Process #618 for roebourne.
# Found: roebourne with city id: 2062276
# Process #619 for pangoa.
# Found: pangoa with city id: 3933104
# Process #620 for tonota.
# Found: tonota with city id: 933000
# Process #621 for palu.
# Found: palu with city id: 1633034
# Process #622 for roald.
# Found: roald with city id: 3141667
# Process #623 for suez.
# Found: suez with city id: 359796
# Process #624 for lompoc.
# Found: lompoc with city id: 5367788
# Process #625 for tucuman.
# Found: tucuman with city id: 3934608
# --------------
#   ALL DONE

# %%
#Making a DataFrame to hold informations pulled from API
weather_df = pd.DataFrame(columns = ["City","Country","Date","Cloudiness","Humidity","Lat","Lng","Max Temp","Wind Speed"])
weather_df["City"] = Cities
weather_df["Country"] = country
weather_df["Date"] = date
weather_df["Cloudiness"] = clouds
weather_df["Humidity"] = humids
weather_df["Lat"] = lats
weather_df["Lng"] = lngs
weather_df["Max Temp"] = max_temps
weather_df["Wind Speed"] = winds
weather_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-35c62285eabc> in <module>
#       6 weather_df["Cloudiness"] = clouds
#       7 weather_df["Humidity"] = humids
# ----> 8 weather_df["Lat"] = lats
#       9 weather_df["Lng"] = lngs
#      10 weather_df["Max Temp"] = max_temps
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# -> 3630             value = sanitize_index(value, self.index, copy=False)
#    3631             if not isinstance(value, (np.ndarray, Index)):
#    3632                 if isinstance(value, list) and len(value) > 0:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     517
#     518     if len(data) != len(index):
# --> 519         raise ValueError('Length of values does not match length of index')
#     520
#     521     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
weather_df.to_csv("Weather.csv")

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, 
#vmax=None, alpha=None, linewidths=None, verts=None, 
#edgecolors=None, *, plotnonfinite=False, data=None, **kwargs

fig,ax = plt.subplots(figsize = (10,8))



ax.scatter(weather_df["Lat"],weather_df["Max Temp"],c=weather_df['Max Temp'], cmap=plt.cm.coolwarm, s = 82);
ax.text(1,60,'EQUATOR', rotation=90, fontdict={"fontsize":8})
ax.vlines(0,20,110)
ax.set_ylim(20,110)

ax.set_title("City Latitude vs Max Temperature")
ax.set_xlabel("Latitudes", fontsize = 16);
ax.set_ylabel("Max Temperatures (°F)", fontsize = 16);

plt.savefig("LatVsTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig,ax = plt.subplots(figsize = (10,8))

ax.scatter(weather_df["Lat"],weather_df["Humidity"], s = 80,c=weather_df['Humidity'], cmap=plt.cm.binary);
ax.text(1,55,'EQUATOR', rotation=90, fontdict={"fontsize":8})
ax.vlines(0,-5,110)
ax.set_ylim(min(weather_df["Humidity"]-10),max(weather_df["Humidity"]+10))

ax.set_title("City Latitude vs Humidity")
ax.set_xlabel("Latitudes", fontsize = 16);
ax.set_ylabel("Humidity", fontsize = 16);

plt.savefig("LatVsHumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig,ax = plt.subplots(figsize = (10,8))

ax.scatter(weather_df["Lat"],weather_df["Cloudiness"], s = 80, c=weather_df['Cloudiness'], cmap=plt.cm.Blues);
ax.text(1,55,'EQUATOR', rotation=90, fontdict={"fontsize":8})
ax.vlines(0,-20,110)
ax.set_ylim(min(weather_df["Cloudiness"]-10),max(weather_df["Cloudiness"]+10))

ax.set_title("City Latitude vs Cloudiness")
ax.set_xlabel("Latitudes", fontsize = 16);
ax.set_ylabel("Cloudiness", fontsize = 16);

plt.savefig("LatVsCloudiness")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig,ax = plt.subplots(figsize = (10,8))

ax.scatter(weather_df["Lat"],weather_df["Wind Speed"], s = 80,c=weather_df['Wind Speed'], cmap=plt.cm.plasma);
ax.text(1,15,'EQUATOR', rotation=90, fontdict={"fontsize":8})
ax.vlines(0,-20,110)
ax.set_ylim(min(weather_df["Wind Speed"]-10),max(weather_df["Wind Speed"]+10))

ax.set_title("City Latitude vs Wind Speed")
ax.set_xlabel("Latitudes", fontsize = 16);
ax.set_ylabel("Wind Speed", fontsize = 16);

plt.savefig("LatVsWindSpeed.png")
